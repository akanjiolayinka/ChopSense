# %% [markdown]
# # ChopSense — Recommendation Exploration

# %% [markdown]
# This notebook is the working scratchpad for exploring the recommendation pipeline.
#
# Use it to inspect the business catalogue, sanity-check embeddings, prototype retrieval queries, and validate re-ranking behaviour before promoting any logic into the main codebase.
